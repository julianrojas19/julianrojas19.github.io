# %% [markdown]
# <a href="https://colab.research.google.com/github/julianrojas19/julianrojas19.github.io/blob/main/proyecto_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('/content/economicas.csv')

# %%
df
# Out:
#      ESTU_CONSECUTIVO  RESULT_CODIGOPRUEBA RESULT_NOMBREPRUEBA  \
# 0      EK202120243329                 2001  ANÁLISIS ECONÓMICO
# 1      EK202120227314                 2001  ANÁLISIS ECONÓMICO
# 2      EK202120088295                 2001  ANÁLISIS ECONÓMICO
# 3      EK202120120119                 2001  ANÁLISIS ECONÓMICO
# 4      EK202120248108                 2001  ANÁLISIS ECONÓMICO
# ...               ...                  ...                 ...
# 3850   EK202120232172                 2001  ANÁLISIS ECONÓMICO
# 3851   EK202120320571                 2001  ANÁLISIS ECONÓMICO
# 3852   EK202120313923                 2001  ANÁLISIS ECONÓMICO
# 3853   EK202120281981                 2001  ANÁLISIS ECONÓMICO
# 3854   EK202120224998                 2001  ANÁLISIS ECONÓMICO
#
#       RESULT_PUNTAJE  RESULT_DESEMPENO ESTU_AGREGADO ESTU_TIPODOCUMENTO  \
# 0                128                 2             S                 CC
# ...

# %%
df.shape
# Out:
# (3855, 97)

# %%
df.columns.str.upper()
# Out:
# Index(['ESTU_CONSECUTIVO', 'RESULT_CODIGOPRUEBA', 'RESULT_NOMBREPRUEBA',
#        'RESULT_PUNTAJE', 'RESULT_DESEMPENO', 'ESTU_AGREGADO',
#        'ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO',
#        'ESTU_FECHANACIMIENTO', 'ESTU_EXTERIOR', 'PERIODO', 'ESTU_ESTUDIANTE',
#        'ESTU_PAIS_RESIDE', 'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO',
#        'ESTU_MCPIO_RESIDE', 'ESTU_COD_RESIDE_MCPIO', 'ESTU_AREARESIDE',
#        'ESTU_COLE_TERMINO', 'ESTU_CODDANE_COLE_TERMINO',
#        'ESTU_COD_COLE_MCPIO_TERMINO', 'ESTU_TITULOOBTENIDOBACHILLER',
#        'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_PAGOMATRICULABECA',
#        'ESTU_PAGOMATRICULACREDITO', 'ESTU_PAGOMATRICULAPADRES',
#        'ESTU_PAGOMATRICULAPROPIO', 'ESTU_COMOCAPACITOEXAMENSB11',
#        'ESTU_TIPODOCUMENTOSB11', 'ESTU_SEMESTRECURSA', 'FAMI_EDUCACIONPADRE',
#        'FAMI_EDUCACIONMADRE', 'FAMI_TRABAJOLABORPADRE',
#        'FAMI_TRABAJOLABORMADRE', 'FAMI_ESTRATOVIVIENDA',
# ...

# %%
df
# Out:
#      ESTU_CONSECUTIVO  RESULT_CODIGOPRUEBA RESULT_NOMBREPRUEBA  \
# 0      EK202120243329                 2001  ANÁLISIS ECONÓMICO
# 1      EK202120227314                 2001  ANÁLISIS ECONÓMICO
# 2      EK202120088295                 2001  ANÁLISIS ECONÓMICO
# 3      EK202120120119                 2001  ANÁLISIS ECONÓMICO
# 4      EK202120248108                 2001  ANÁLISIS ECONÓMICO
# ...               ...                  ...                 ...
# 3850   EK202120232172                 2001  ANÁLISIS ECONÓMICO
# 3851   EK202120320571                 2001  ANÁLISIS ECONÓMICO
# 3852   EK202120313923                 2001  ANÁLISIS ECONÓMICO
# 3853   EK202120281981                 2001  ANÁLISIS ECONÓMICO
# 3854   EK202120224998                 2001  ANÁLISIS ECONÓMICO
#
#       RESULT_PUNTAJE  RESULT_DESEMPENO ESTU_AGREGADO ESTU_TIPODOCUMENTO  \
# 0                128                 2             S                 CC
# ...

# %%
economista = df.filter(['ESTU_CONSECUTIVO	','RESULT_PUNTAJE','RESULT_DESEMPENO','ESTU_GENERO','ESTU_PRGM_ACADEMICO','ESTU_SNIES_PRGMACADEMICO', 'GRUPOREFERENCIA','MOD_RAZONA_CUANTITAT_PUNT', 'MOD_LECTURA_CRITICA_PUNT','MOD_COMPETEN_CIUDADA_PUNT', 'MOD_INGLES_PUNT', 'MOD_COMUNI_ESCRITA_PUNT', 'PUNT_GLOBAL','PERCENTIL_GLOBAL'])

# %%
economista
# Out:
#       RESULT_PUNTAJE  RESULT_DESEMPENO ESTU_GENERO ESTU_HORASSEMANATRABAJA  \
# 0                128                 2           M         Más de 30 horas
# 1                209                 4           M                       0
# 2                106                 1           M     Entre 21 y 30 horas
# 3                 89                 1           F         Más de 30 horas
# 4                122                 1           M         Más de 30 horas
# ...              ...               ...         ...                     ...
# 3850             151                 2           M         Más de 30 horas
# 3851             162                 3           F       Menos de 10 horas
# 3852               0                 1           F         Más de 30 horas
# 3853             110                 1           F     Entre 21 y 30 horas
# 3854             115                 1           M                     NaN
#
#                     ESTU_PRGM_ACADEMICO  ESTU_SNIES_PRGMACADEMICO  \
# ...

# %%
economista.count()
# Out:
# RESULT_PUNTAJE               3855
# RESULT_DESEMPENO             3855
# ESTU_GENERO                  3855
# ESTU_HORASSEMANATRABAJA      3723
# ESTU_PRGM_ACADEMICO          3855
# ESTU_SNIES_PRGMACADEMICO     3855
# GRUPOREFERENCIA              3855
# MOD_RAZONA_CUANTITAT_PUNT    3855
# MOD_LECTURA_CRITICA_PUNT     3855
# MOD_COMPETEN_CIUDADA_PUNT    3855
# MOD_INGLES_PUNT              3855
# MOD_COMUNI_ESCRITA_PUNT      3855
# PUNT_GLOBAL                  3855
# PERCENTIL_GLOBAL             3855
# dtype: int64

# %%
from scipy.spatial.distance import mahalanobis
from scipy.stats import chi2
import scipy.stats as stats

# %%
multipydf = economista.corr()
f, ax=plt.subplots(figsize=(11, 8))
sns.heatmap(multipydf, vmax=.9, square=True)

# %%
sns.heatmap(economista.corr(), annot=True)

# %%
sns.heatmap(economista.corr(method='spearman'), annot=True)

# %%
sns.heatmap(economista.cov(), annot=True)
